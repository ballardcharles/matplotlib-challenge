# %% [markdown]
# # Observations
#
# ### 1. The number of measurements is pretty consistent across the different drug regimens.  This should help with consistency and reliability of results when comparing drug regimes.
#
# ### 2. The ratio of male to female mice was near 1:1 which should help reliability of the drug regimen results across genders.
#
# ### 3. The drug regimen Capomulin when compared to Ramicane, Infubinol, and Ceftamin seemed to have the best results for reducing tumor volume over time.
#
# ### 4. There appears to be a strong to very strong correlation between mouse weight and tumor volume.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_mouse = pd.merge(mouse_metadata, study_results, on='Mouse ID')
# Display the data table for preview
combined_mouse.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Check the number of mice.
combined_mouse.count()
# Out:
# Mouse ID              1893
# Drug Regimen          1893
# Sex                   1893
# Age_months            1893
# Weight (g)            1893
# Timepoint             1893
# Tumor Volume (mm3)    1893
# Metastatic Sites      1893
# dtype: int64

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicated_data = combined_mouse[combined_mouse.duplicated(['Mouse ID','Timepoint'])]
duplicated_data
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Display data from duplicate mouse id
duplicate_mouse = combined_mouse.loc[combined_mouse['Mouse ID'] == 'g989', :]
duplicate_mouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1
# 918           56.045564                 1
# 919           59.082294                 1
# 920           62.570880                 2

# %%
# Drop duplicate mouse ID and display the count of data
clean_mouse_df = combined_mouse.drop_duplicates(['Mouse ID', 'Timepoint'])
clean_mouse_df.count()
# Out:
# Mouse ID              1888
# Drug Regimen          1888
# Sex                   1888
# Age_months            1888
# Weight (g)            1888
# Timepoint             1888
# Tumor Volume (mm3)    1888
# Metastatic Sites      1888
# dtype: int64

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

regimen_group = clean_mouse_df.groupby('Drug Regimen')
tumor_vol = regimen_group['Tumor Volume (mm3)']
# Calculate mean for regimen group by Tumor Volume
mean_tumor_vol = tumor_vol.mean()

# Calculate median for regimen group by Tumor Volume
median_tumor_vol = tumor_vol.median()

# Calculate variance for regimen group by Tumor Volume
var_tumor_vol = tumor_vol.var()

# Calculate standard deviation for regimen group by Tumor Volume
sd_tumor_vol = tumor_vol.std()

# Calculate the SEM for regimen by Tumor Volume
sem_tumor_vol = tumor_vol.sem()

# Create dataframe for summary stats for regimen by Tumor Volume
sum_stats_regimen = pd.DataFrame({
    'Mean':mean_tumor_vol,
    'Median':median_tumor_vol,
    'Variance':var_tumor_vol,
    'Standard Deviation':sd_tumor_vol,
    'SEM':sem_tumor_vol,
})
sum_stats_regimen
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803            6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Use the aggregate methode to create a summary statistics table.
tumor_vol.agg(['mean', 'median', 'var', 'std', 'sem'])
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803  6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
# Get the count of mouse measurements by regimen group
num_measure = regimen_group['Mouse ID'].count()
#plot and format bar chart to reflect the number of measurements by regimen group.
num_measure.plot(kind='bar', color='r', alpha=0.5, align="center", figsize=(12,5))
plt.title('Total Number of Measurements by Drug Regimen')
plt.ylabel('Number of Measurements Taken')
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
# Get the count of mouse measurements by regimen group
regimen = clean_mouse_df['Drug Regimen'].unique()
# Sort regimen by name.
regimen.sort()
# Plot and format bar chart for measurments by regimen group.
plt.figure(figsize=(12,5))
plt.bar(regimen, num_measure, color='r', alpha=0.5, width = .5, align="center")

plt.title('Total Number of Measurements by Drug Regimen')
plt.ylabel('Number of Measurements Taken')

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
# Calculate the number of male and female mice in the study.
gender_dist = clean_mouse_df['Sex'].value_counts()
# Set formating and plot pie chart for male vs. female mice in the study.
explode = (0,0.05)
gender_dist.plot(kind='pie', explode=explode, autopct='%1.1f%%', shadow=True, startangle=45, subplots=True)
plt.title('Male vs. Female')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
# Set formating and plot pie chart for male vs. female mice in the study.
genders = ('Male', 'Female')
plt.pie(gender_dist, explode=explode, labels=genders, autopct='%1.1f%%', shadow=True, startangle=45)
plt.ylabel('Sex')
plt.title('Male vs. Female')
plt.show()

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
mouse_group = clean_mouse_df.groupby('Mouse ID')

last_timepoint = mouse_group['Timepoint'].max()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
last_tp_merge = pd.merge(clean_mouse_df, last_timepoint, on='Mouse ID')
# Drop duplicates to simplify the dataframe to better find the last timepoint measurement.
last_tp_clean = last_tp_merge.drop_duplicates(['Mouse ID', 'Timepoint_y'], keep='last')
last_tp_clean = last_tp_clean.drop(columns='Timepoint_y')

# %%
# Put treatments into a list for for loop (and later for plot labels)
drug_regimen = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list = []
# Use for loop to Calculate the IQR and quantitatively determine if there are any potential outliers. 
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # add subset 
    # Determine outliers using upper and lower bounds

for drug in drug_regimen:
    
    drug_df = last_tp_clean.loc[last_tp_clean['Drug Regimen'] == drug]
    # Get last measurment and add to list
    tumor_value = drug_df['Tumor Volume (mm3)']
    tumor_vol_list.append(tumor_value)
    # Calculate quartiles, lower/upper quartiles and bounds.
    quartiles = tumor_value.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = round(upperq-lowerq,2)
    lower_bound = round(lowerq - (1.5*iqr),2)
    upper_bound = round(upperq + (1.5*iqr),2)
    # Print calulations to terminal to review data. 
    print(f'----------------------------------------')
    print(f'IQR for {drug}: {iqr}')
    print(f'Lower Bound for {drug}: {lowerq}')
    print(f'Upper Bound for {drug}: {upperq}')
    print(f"The the median of {drug} is: {round(quartiles[0.5],2)} ")
    print(f"Values below {lower_bound} for {drug} could be outliers.")
    print(f"Values above {upper_bound} for {drug} could be outliers.")
    outlier_count = (tumor_value.loc[(drug_df['Tumor Volume (mm3)'] >= upper_bound) | 
                                        (drug_df['Tumor Volume (mm3)'] <= lower_bound)]).count()
    print(f"{drug} has {outlier_count} outliers.")
    
print(f'----------------------------------------')
# Out:
# ----------------------------------------
# IQR for Capomulin: 7.78
# Lower Bound for Capomulin: 32.37735684
# Upper Bound for Capomulin: 40.1592203
# The the median of Capomulin is: 38.13
# Values below 20.71 for Capomulin could be outliers.
# Values above 51.83 for Capomulin could be outliers.
# Capomulin has 0 outliers.
# ----------------------------------------
# IQR for Ramicane: 9.1
# Lower Bound for Ramicane: 31.56046955
# Upper Bound for Ramicane: 40.65900627
# The the median of Ramicane is: 36.56
# Values below 17.91 for Ramicane could be outliers.
# Values above 54.31 for Ramicane could be outliers.
# Ramicane has 0 outliers.
# ----------------------------------------
# IQR for Infubinol: 11.48
# Lower Bound for Infubinol: 54.04860769
# Upper Bound for Infubinol: 65.52574285
# The the median of Infubinol is: 60.17
# Values below 36.83 for Infubinol could be outliers.
# Values above 82.75 for Infubinol could be outliers.
# Infubinol has 1 outliers.
# ----------------------------------------
# IQR for Ceftamin: 15.58
# Lower Bound for Ceftamin: 48.72207785
# Upper Bound for Ceftamin: 64.29983003
# The the median of Ceftamin is: 59.85
# Values below 25.35 for Ceftamin could be outliers.
# Values above 87.67 for Ceftamin could be outliers.
# Ceftamin has 0 outliers.
# ----------------------------------------

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
# Create format for outlier marker
flierprops = dict(marker='o', markerfacecolor='red', markersize=8,
                  linestyle='none')
# Plot and format boxplot for the four requested drug regimens
plt.boxplot(tumor_vol_list, labels=drug_regimen, flierprops=flierprops)
plt.title("Tumor Volume by Drug Regimen")
plt.ylabel("Tumor Volume")
plt.xlabel("Drug Regimen")

plt.show()

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# Grab data points for single mouse that was treated with Capomulin
s185_tumor = clean_mouse_df['Tumor Volume (mm3)'].loc[clean_mouse_df['Mouse ID'] == 's185']

s185_timepoint = clean_mouse_df['Timepoint'].loc[clean_mouse_df['Mouse ID'] == 's185']
# Format and plot line graph to show measurments over time for single mouse using Capomulin
plt.plot(s185_timepoint,s185_tumor, marker='o', color='red')
plt.title('Mouse S185 with Capomulin Regimen')
plt.ylabel('Tumor Size')
plt.xlabel('Timepoint')

plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
# Create list of mice that were treated with Capomulin to loop through and grab average tumor volume and mouse weight.
mouse_id = ['s185', 'x401', 'm601', 'f966', 'u364', 'y793', 'r554', 'm957',
       't565', 'i738', 'w914', 'g288', 'l897', 'b742', 'b128', 'j246',
       'j119', 'w150', 'v923', 'g316', 's710', 'l509', 'r944', 'i557',
       'r157']
# Create empty lists for for loop to house data of average tumor volume and mouse weight.
avg_tumor_list = []
mouse_weight_list = []
# Loop through data frame creating list of data points to plot.
for mouse in mouse_id:
    
    mouse_df = clean_mouse_df.loc[clean_mouse_df['Mouse ID'] == mouse]
    
    avg_tumor_vol = mouse_df['Tumor Volume (mm3)'].mean()
    avg_tumor_list.append(avg_tumor_vol)
    
    weight_df = last_tp_clean.loc[last_tp_clean['Mouse ID'] == mouse]
    mouse_weight =  weight_df['Weight (g)'].values[0]
    mouse_weight_list.append(mouse_weight)

# House the lists in a data frame
Capomulin_df = pd.DataFrame({'Mouse ID':mouse_id,
                            'Avg Tumor Vol':avg_tumor_list,
                            'Weight (g)':mouse_weight_list})
# Plot and format mouse weight vs. average tumor volume on scatter plot.
plt.scatter(mouse_weight_list,avg_tumor_list)
plt.title('Tumor Volume vs Mouse Weight for Capomulin Regimen')
plt.ylabel('Mouse Weight')
plt.xlabel('Tumor')
# Out:
# Text(0.5, 0, 'Tumor')

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen


(slope, intercept, rvalue, pvalue, stderr) = linregress(mouse_weight_list,avg_tumor_list)
regress_values = np.array(mouse_weight_list) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(mouse_weight_list,avg_tumor_list)
plt.plot(mouse_weight_list,regress_values,"r-")
plt.annotate(line_eq,(20,38),fontsize=15,color="red")
plt.title('Tumor Volume vs Mouse Weight for Capomulin Regimen')
plt.ylabel('Mouse Weight')
plt.xlabel('Tumor Volume')

plt.show()
# Print the correclation coefficent betwen tumor volume and mouse weight to show strength of correlation
print(f"The correlation coefficient between tumor volume and mouse weight is {round(st.pearsonr(avg_tumor_list, mouse_weight_list)[0],2)}")
# Out:
# The correlation coefficient between tumor volume and mouse weight is 0.84
